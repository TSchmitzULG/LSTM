# %% [markdown]
# # Learn simple layer of LSTM

# %% [markdown]
# See the installation file to be able to run this file.
# If you find this file usefull, please cite the corresponding ICASSP2018 doi reference in your work.

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
"""lstm for guitar signal with input feature for gain parameters, jupyter notebook version"""
import os
import sys
sys.path.append('Codes')
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import pickle
from dataShaping import *
from savePerf import *
import scipy.io.wavfile
import time
from tensorflow.python.tools import freeze_graph


modelName = "LSTM9_ICASSP"
# create directory experiment
date = time.strftime("%Y-%m-%d-%H-%M")
path = os.path.join("experiments",date)
if not os.path.isdir(path):
    os.makedirs(path)
    #experiment/"date"/temp will contain the backuped model parameters
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)
    # if you run the file two time in a minute
else :
    date = date+'(2)'
    path = os.path.join("experiments",date)
    os.makedirs(path)
    pathTemp = os.path.join(path,'temp')
    os.makedirs(pathTemp)
	
# directory that will contain tensorboard information
pathLog = 'tf_logs'
if not os.path.isdir(pathLog):
    os.makedirs(pathLog)
pathLog = "{}/run-{}/".format(pathLog,date)

version = tf.__version__
print ("version {} of tensorflow".format(version))

#############################
# Model parameters
#############################
trainTestRatio = 0.9
#if you cannot load all the data set in Ram specify wich part you want to load (0 means all the dataset)
maxSize = int(np.floor(44100*11.4))
num_step = 100                                          #time step
num_hidden = 100                                      #num of hidden units
num_class = 1                                          #size of the output
num_feature = 1                                        # size of the input
batch_size = 600                                      # number of sequence taken before to compute the gradient
n_layer =1                                             #num_layer
num_epoch = 100000                                       # process all the datas num_epoch times
trainDuration = 60*60*24                               # or during a determined duration(second)
fileName = 'Datasets/training.mat'             #dataset train/test path
fileNameValidation = 'Datasets/validation.mat' # dataset validation path


#############################
# Loading data
#############################
matrix = sio.loadmat(fileName)
matrix = matrix['training']
if maxSize ==0:
    maxSize = len(matrix)
    print(maxSize)
# to do shuffle matrix by num_step length
train_input,train_output,test_input,test_output = splitShuffleData(matrix,num_step,trainTestRatio,maxSize)
print("shape input train {}".format(np.shape(train_input)))
numTrain = len(train_output)
print ("Data loaded")
#######################
#Graph
#######################

G = tf.Graph()
with G.as_default():
    with tf.name_scope("placeHolder"):
        data = tf.placeholder(tf.float32, [None, num_step], name ="data") #Number of examples, number of input step (time step), dimension of each input
        target = tf.placeholder(tf.float32, [None, num_class],name = "target") # batchSize, nbClass

    dataShaped = tf.reshape(data,[tf.shape(data)[0],num_step,num_feature])
    
    def lstm_cell():
        return tf.contrib.rnn.LSTMCell(num_hidden,state_is_tuple=True,activation = tf.nn.tanh)
    
    multiLayerCell = tf.contrib.rnn.MultiRNNCell([lstm_cell() for _ in range(n_layer)] )

    with tf.name_scope("extractLastValueLSTM"):
        val, state = tf.nn.dynamic_rnn(multiLayerCell, dataShaped, dtype=tf.float32) # val dim is [batchSize,sequencelength, numhidden]
    # Let's first fetch the last index of seq length
    # last_index would have a scalar value
        last_index = tf.shape(val)[1] - 1
    # Then let's reshape the output to [sequence_length,batch_size,numhidden]
    # for convenience
        val = tf.transpose(val,[1,0,2])
    # Last state of all batches
        last = tf.nn.embedding_lookup(val,last_index) # tensor [batchsize,numhidden]

    #Send the output of the lsat LSTM cell into a Fully connected layer to compute the prediciton pred[n]  
    with tf.name_scope("FCLayer"):
        weight = tf.get_variable("weight", shape=[num_hidden, int(target.get_shape()[1])], initializer=tf.contrib.layers.xavier_initializer())
        bias = tf.Variable(tf.constant(0.1, shape=[target.get_shape()[1]]))

    prediction = tf.nn.elu((tf.add(tf.matmul(last, weight) , bias)),name = "prediction") #[batchSize,nclass]

    #Compute the mean square error
    MSE = tf.reduce_mean(tf.square(prediction-target))
    
    # create optimizer
    optimizer = tf.train.AdamOptimizer()
    #Compute gradient and apply backpropagation
    minimize = optimizer.minimize(MSE)

    # Create summary view for tensorboard
    mse_summary = tf.summary.scalar('RMSE',tf.sqrt(MSE))
    summary_op = tf.summary.merge_all()
    
    #Create an init op to initialize variable
    init_op = tf.global_variables_initializer()
    saver = tf.train.Saver() # save variable, use saver.restore(sess,"date/tmp/my_model.ckpt") instead of sess.run(init_op)

##############################
# Execution du graphe
##############################
    
with tf.Session(graph=G) as sess:
    #restorePath = os.path.join('2017-09-11-18-07','temp','my_model.ckpt') # example for restore a previous model
    #saver.restore(sess,restorePath)
    sess.run(init_op)
    train_writer = tf.summary.FileWriter(pathLog+'train',graph =tf.get_default_graph())
    test_writer = tf.summary.FileWriter(pathLog+'test')

    no_of_batches = int(np.floor((numTrain)/batch_size)) # numtrain -numstep ?
    no_of_batchesTest = int(np.floor((len(test_input))/batch_size))
    tStart = time.clock()
    epoch =0
    for epoch in range(num_epoch):
        if (time.clock()-tStart < trainDuration):
            ptr = 0
            if epoch % 10==0 : # each ten epoch save the model
                tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myGraph.pb',as_text=False)
                save_path = saver.save(sess,os.path.join(pathTemp,'my_model.ckpt'))
            for j in range(no_of_batches):
                inp, out = train_input[ptr:ptr+batch_size],train_output[ptr:ptr+batch_size]
                
                ptr+=batch_size
                if j % np.floor(trainTestRatio*10) ==0 : # This is to have a train summary and a test summary of the same size
                    _,summary_str = sess.run([minimize,summary_op],{data: inp, target: out})
                    step = epoch*no_of_batches+j
                    train_writer.add_summary(summary_str,step)
                else :
                    sess.run([minimize],{data: inp, target: out})
                   
                #print value
            print ("Epoch -{} calculated ".format(epoch))
            # evaluate the model on the test set (compute the mean of the MSE)
            pMSE = 0
            ptr2 = 0
            for k in range(no_of_batchesTest):
                pMSETemp,summary_str = sess.run([MSE,summary_op],{data: test_input[ptr2:ptr2+batch_size] , target: test_output[ptr2:ptr2+batch_size]})
                pMSE += pMSETemp
                ptr2+=batch_size
                step = epoch*no_of_batchesTest+k
                test_writer.add_summary(summary_str,step*10*trainTestRatio)
            print("Epoch {} MSE {} on test set".format(epoch,np.sqrt(pMSE/no_of_batchesTest)))
        else : break # break the while loop if number of epoch is reached
    tStop = time.clock()
    trainTime = time.strftime("%d:%H:%M:%S ", time.gmtime(tStop-tStart))
    
    #######################
    # Save Graph variable and information about the running session
    #######################
    # save graph model
    tf.train.write_graph(sess.graph_def,"{}/".format(pathTemp),'myFinalGraph.pb',as_text=False)
    # Save checkpoint variables
    save_path = saver.save(sess,os.path.join(pathTemp,'myFinalModel.ckpt'))
    print ("Training duration {}".format(trainTime))
    totalParameters =np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()])
    print("Number of training variable {}".format(totalParameters))
    # log
    infoLog={}
    infoLog["path"] = path
    infoLog["MSE"] = np.sqrt(pMSE/no_of_batchesTest)
    infoLog["num_step"] = num_step
    infoLog["num_hidden"] = num_hidden
    infoLog["num_epoch"] = epoch
    infoLog["batch_size"] = batch_size
    infoLog["maxSize"] = maxSize
    infoLog["duration"] = trainTime
    infoLog["totalParameters"] = totalParameters
    infoLog["version"] = version
    infoLog["n_layer"] = n_layer
    infoLog["trainDropout"] = 0
    infoLog["nameModel"] = modelName
    logPerf(infoLog)
    # freeze graph
    input_graph_path = "{}/".format(pathTemp)+'myFinalGraph.pb'
    checkpoint_path = "{}/".format(pathTemp)+'myFinalModel.ckpt'
    input_saver_def_path = ""
    input_binary = True
    output_node_names = "prediction"
    restore_op_name = "save/restore_all"
    filename_tensor_name = "save/Const:0"
    output_frozen_graph_name = "{}/".format(pathTemp)+'frozenModel.pb'
    # output_optimized_graph_name = 'optimized_'+MODEL_NAME+'.pb'
    clear_devices = True
    freeze_graph.freeze_graph(input_graph_path, input_saver_def_path,
                          input_binary, checkpoint_path, output_node_names,
                          restore_op_name, filename_tensor_name,
                          output_frozen_graph_name, clear_devices, "")
   
    
    ###############################
    #   validation dataset and emulate guitar signal
    ###############################
    matrixVal = sio.loadmat(fileNameValidation)
    matrixVal = matrixVal['validation']  
    # shape validation test
    val_input,val_output = shapeData(matrixVal,num_step,maxSize)
    lPrediction = []
    lTarget = []
    ptr3 = 0
    no_of_batchesVal = int(np.floor((len(val_input))/batch_size))
    for k in range(no_of_batchesVal):
        pPrediction,pTarget = sess.run([prediction,target],{data: val_input[ptr3:ptr3+batch_size], target: val_output[ptr3:ptr3+batch_size]}) 
        lPrediction.append(pPrediction)
        lTarget.append(pTarget)   
        ptr3+=batch_size
    #plt.show()scree
    predictionArray = np.array(lPrediction,dtype=np.float32).ravel()
    targetArray = np.array(lTarget,dtype=np.float32).ravel()
    scipy.io.wavfile.write(os.path.join(path,'prediction.wav'),44100,predictionArray)
    scipy.io.wavfile.write(os.path.join(path,'target.wav'),44100,targetArray)

    # save emulation in a pickle format
    ax = plt.subplot(111)
    ax.plot(predictionArray[:10000],label='prediction')
    ax.plot(targetArray[:10000],label='target')
    ax.legend()
    nameFigEstimation = os.path.join(path,"targetVsPrediction.pickle")
    pickle.dump(ax,open(nameFigEstimation, 'wb'))
print ("done, good job kids")
# Out:
# version 1.3.0 of tensorflow
# shape input train (452466, 100)
# Data loaded
# /home/totovai/Documents/Doctorat/NeuralNetwork/env/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:95: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch -0 calculated
# Epoch 0 MSE 0.13459073292215323 on test set
# Epoch -1 calculated
# Epoch 1 MSE 0.10896037474953406 on test set
# Epoch -2 calculated
# Epoch 2 MSE 0.10154234118895747 on test set
# Epoch -3 calculated
# Epoch 3 MSE 0.10013552007585896 on test set
# Epoch -4 calculated
# Epoch 4 MSE 0.09882192023504367 on test set
# Epoch -5 calculated
# Epoch 5 MSE 0.09712634214351465 on test set
# Epoch -6 calculated
# Epoch 6 MSE 0.09658358946274982 on test set
# Epoch -7 calculated
# Epoch 7 MSE 0.09555485762354636 on test set
# Epoch -8 calculated
# Epoch 8 MSE 0.09526304975644094 on test set
# Epoch -9 calculated
# Epoch 9 MSE 0.09398428922457364 on test set
# Epoch -10 calculated
# Epoch 10 MSE 0.09264886535006643 on test set
# Epoch -11 calculated
# Epoch 11 MSE 0.09151425333481807 on test set
# Epoch -12 calculated
# Epoch 12 MSE 0.09044978827090802 on test set
# Epoch -13 calculated
# Epoch 13 MSE 0.08977691473435206 on test set
# Epoch -14 calculated
# Epoch 14 MSE 0.08870151353427046 on test set
# Epoch -15 calculated
# Epoch 15 MSE 0.08780546409626037 on test set
# Epoch -16 calculated
# Epoch 16 MSE 0.08658009665696176 on test set
# Epoch -17 calculated
# Epoch 17 MSE 0.08563945761419331 on test set
# Epoch -18 calculated
# Epoch 18 MSE 0.08504789847621068 on test set
# Epoch -19 calculated
# Epoch 19 MSE 0.0848642349837457 on test set
# Epoch -20 calculated
# Epoch 20 MSE 0.0856158435232545 on test set
# Epoch -21 calculated
# Epoch 21 MSE 0.08495344691054937 on test set
# Epoch -22 calculated
# Epoch 22 MSE 0.0841878362796827 on test set
# Epoch -23 calculated
# Epoch 23 MSE 0.08316667556910255 on test set
# Epoch -24 calculated
# Epoch 24 MSE 0.0839695693975771 on test set
# Epoch -25 calculated
# Epoch 25 MSE 0.08229108563007816 on test set
# Epoch -26 calculated
# Epoch 26 MSE 0.08244436700107234 on test set
# Epoch -27 calculated
# Epoch 27 MSE 0.08154014545086054 on test set
# Epoch -28 calculated
# Epoch 28 MSE 0.08340301003727885 on test set
# Epoch -29 calculated
# Epoch 29 MSE 0.0823515463574531 on test set
# Epoch -30 calculated
# Epoch 30 MSE 0.08119399137220214 on test set
# Epoch -31 calculated
# Epoch 31 MSE 0.07967952418678792 on test set
# Epoch -32 calculated
# Epoch 32 MSE 0.08073690193498281 on test set
# Epoch -33 calculated
# Epoch 33 MSE 0.07923162813972498 on test set
# Epoch -34 calculated
# Epoch 34 MSE 0.07896938249680725 on test set
# Epoch -35 calculated
# Epoch 35 MSE 0.07823845455773257 on test set
# Epoch -36 calculated
# Epoch 36 MSE 0.07798605625851987 on test set
# Epoch -37 calculated
# Epoch 37 MSE 0.07724779828113493 on test set
# Epoch -38 calculated
# Epoch 38 MSE 0.07547295811327372 on test set
# Epoch -39 calculated
# Epoch 39 MSE 0.07466707393413181 on test set
# Epoch -40 calculated
# Epoch 40 MSE 0.07419678638825139 on test set
# Epoch -41 calculated
# Epoch 41 MSE 0.07468103239840738 on test set
# Epoch -42 calculated
# Epoch 42 MSE 0.0734540118328726 on test set
# Epoch -43 calculated
# Epoch 43 MSE 0.07248933250503824 on test set
# Epoch -44 calculated
# Epoch 44 MSE 0.07170850009648001 on test set
# Epoch -45 calculated
# Epoch 45 MSE 0.07153537530007674 on test set
# Epoch -46 calculated
# Epoch 46 MSE 0.07348225797628834 on test set
# Epoch -47 calculated
# Epoch 47 MSE 0.07072753877852081 on test set
# Epoch -48 calculated
# Epoch 48 MSE 0.07031266802186181 on test set
# Epoch -49 calculated
# Epoch 49 MSE 0.06928022404797674 on test set
# Epoch -50 calculated
# Epoch 50 MSE 0.06996812629748103 on test set
# Epoch -51 calculated
# Epoch 51 MSE 0.06952666302800739 on test set
# Epoch -52 calculated
# Epoch 52 MSE 0.067157460432235 on test set
# Epoch -53 calculated
# Epoch 53 MSE 0.06686037615075364 on test set
# Epoch -54 calculated
# Epoch 54 MSE 0.06659152156634814 on test set
# Epoch -55 calculated
# Epoch 55 MSE 0.06703805535068166 on test set
# Epoch -56 calculated
# Epoch 56 MSE 0.06556869929902231 on test set
# Epoch -57 calculated
# Epoch 57 MSE 0.06466627334710875 on test set
# Epoch -58 calculated
# Epoch 58 MSE 0.06511519157510846 on test set
# Epoch -59 calculated
# Epoch 59 MSE 0.06393038362974157 on test set
# Epoch -60 calculated
# Epoch 60 MSE 0.06573299971135775 on test set
# Epoch -61 calculated
# Epoch 61 MSE 0.06384357424296637 on test set
# Epoch -62 calculated
# Epoch 62 MSE 0.062477791775715316 on test set
# Epoch -63 calculated
# Epoch 63 MSE 0.06202285197288714 on test set
# Epoch -64 calculated
# Epoch 64 MSE 0.06389853199477247 on test set
# Epoch -65 calculated
# Epoch 65 MSE 0.060978730466154915 on test set
# Epoch -66 calculated
# Epoch 66 MSE 0.06180767524685093 on test set
# Epoch -67 calculated
# Epoch 67 MSE 0.05977740457069239 on test set
# Epoch -68 calculated
# Epoch 68 MSE 0.06096400749102347 on test set
# Epoch -69 calculated
# Epoch 69 MSE 0.059540473037207664 on test set
# Epoch -70 calculated
# Epoch 70 MSE 0.058544523437164424 on test set
# Epoch -71 calculated
# Epoch 71 MSE 0.05834998390622537 on test set
# Epoch -72 calculated
# Epoch 72 MSE 0.05766654583057449 on test set
# Epoch -73 calculated
# Epoch 73 MSE 0.0569491877951468 on test set
# Epoch -74 calculated
# Epoch 74 MSE 0.056615541639748766 on test set
# Epoch -75 calculated
# Epoch 75 MSE 0.05593928059745615 on test set
# Epoch -76 calculated
# Epoch 76 MSE 0.05550442966767377 on test set
# Epoch -77 calculated
# Epoch 77 MSE 0.05442588610152947 on test set
# Epoch -78 calculated
# Epoch 78 MSE 0.05337644224594572 on test set
# Epoch -79 calculated
# Epoch 79 MSE 0.05288355472397656 on test set
# Epoch -80 calculated
# Epoch 80 MSE 0.05229719431008847 on test set
# Epoch -81 calculated
# Epoch 81 MSE 0.05295974817225641 on test set
# Epoch -82 calculated
# Epoch 82 MSE 0.05146160559231279 on test set
# Epoch -83 calculated
# Epoch 83 MSE 0.057333224327074675 on test set
# Epoch -84 calculated
# Epoch 84 MSE 0.05075771684268557 on test set
# Epoch -85 calculated
# Epoch 85 MSE 0.0512327080032107 on test set
# Epoch -86 calculated
# Epoch 86 MSE 0.051123791931951656 on test set
# Epoch -87 calculated
# Epoch 87 MSE 0.050253802792848995 on test set
# Epoch -88 calculated
# Epoch 88 MSE 0.05022186352929503 on test set
# Epoch -89 calculated
# Epoch 89 MSE 0.050165886008367445 on test set
# Epoch -90 calculated
# Epoch 90 MSE 0.05006529943080458 on test set
# Epoch -91 calculated
# Epoch 91 MSE 0.04978942014709782 on test set
# Epoch -92 calculated
# Epoch 92 MSE 0.049934689672737044 on test set
# Epoch -93 calculated
# Epoch 93 MSE 0.0482662840472067 on test set
# Epoch -94 calculated
# Epoch 94 MSE 0.0503044066327944 on test set
# Epoch -95 calculated
# Epoch 95 MSE 0.048113304326252215 on test set
# Epoch -96 calculated
# Epoch 96 MSE 0.050557982045052276 on test set
# Epoch -97 calculated
# Epoch 97 MSE 0.04837464270173629 on test set
# Epoch -98 calculated
# Epoch 98 MSE 0.04765413079997317 on test set
# Epoch -99 calculated
# Epoch 99 MSE 0.046847650545005365 on test set
# Epoch -100 calculated
# Epoch 100 MSE 0.047692138883903626 on test set
# Epoch -101 calculated
# Epoch 101 MSE 0.04751940370928346 on test set
# Epoch -102 calculated
# Epoch 102 MSE 0.04679494669734616 on test set
# Epoch -103 calculated
# Epoch 103 MSE 0.04742328714076976 on test set
# Epoch -104 calculated
# Epoch 104 MSE 0.04623967886404804 on test set
# Epoch -105 calculated
# Epoch 105 MSE 0.04684002462350919 on test set
# Epoch -106 calculated
# Epoch 106 MSE 0.04684198643163898 on test set
# Epoch -107 calculated
# Epoch 107 MSE 0.0467543992960542 on test set
# Epoch -108 calculated
# Epoch 108 MSE 0.04657444068680664 on test set
# Epoch -109 calculated
# Epoch 109 MSE 0.048652635340238795 on test set
# Epoch -110 calculated
# Epoch 110 MSE 0.04595641023410538 on test set
# Epoch -111 calculated
# Epoch 111 MSE 0.04861289927723132 on test set
# Epoch -112 calculated
# Epoch 112 MSE 0.045341055581689604 on test set
# Epoch -113 calculated
# Epoch 113 MSE 0.04497068127019219 on test set
# Epoch -114 calculated
# Epoch 114 MSE 0.04497549663774007 on test set
# Epoch -115 calculated
# Epoch 115 MSE 0.04485735748809429 on test set
# Epoch -116 calculated
# Epoch 116 MSE 0.04547004417563237 on test set
# Epoch -117 calculated
# Epoch 117 MSE 0.04538796933078907 on test set
# Epoch -118 calculated
# Epoch 118 MSE 0.04461216453594907 on test set
# Epoch -119 calculated
# Epoch 119 MSE 0.044893333511105776 on test set
# Epoch -120 calculated
# Epoch 120 MSE 0.043952886983177425 on test set
# Epoch -121 calculated
# Epoch 121 MSE 0.043676642764750626 on test set
# Epoch -122 calculated
# Epoch 122 MSE 0.04466323133997108 on test set
# Epoch -123 calculated
# Epoch 123 MSE 0.04320032554614217 on test set
# Epoch -124 calculated
# Epoch 124 MSE 0.04396508484112894 on test set
# Epoch -125 calculated
# Epoch 125 MSE 0.044214885590915756 on test set
# Epoch -126 calculated
# Epoch 126 MSE 0.04325888643338603 on test set
# Epoch -127 calculated
# Epoch 127 MSE 0.04273908721078678 on test set
# Epoch -128 calculated
# Epoch 128 MSE 0.042078206698136014 on test set
# Epoch -129 calculated
# Epoch 129 MSE 0.04196159210699247 on test set
# Epoch -130 calculated
# Epoch 130 MSE 0.0416570067200551 on test set
# Epoch -131 calculated
# Epoch 131 MSE 0.041956901972992115 on test set
# Epoch -132 calculated
# Epoch 132 MSE 0.041689720961423704 on test set
# Epoch -133 calculated
# Epoch 133 MSE 0.041522239546597485 on test set
# Epoch -134 calculated
# Epoch 134 MSE 0.04142413003353422 on test set
# Epoch -135 calculated
# Epoch 135 MSE 0.04165579452947374 on test set
# Epoch -136 calculated
# Epoch 136 MSE 0.0406112535599437 on test set
# Epoch -137 calculated
# Epoch 137 MSE 0.04270205150089657 on test set
# Epoch -138 calculated
# Epoch 138 MSE 0.04103002185091643 on test set
# Epoch -139 calculated
# Epoch 139 MSE 0.04020966708131117 on test set
# Epoch -140 calculated
# Epoch 140 MSE 0.04096388732274798 on test set
# Epoch -141 calculated
# Epoch 141 MSE 0.040442874649595145 on test set
# Epoch -142 calculated
# Epoch 142 MSE 0.04047746918097516 on test set
# Epoch -143 calculated
# Epoch 143 MSE 0.04074566914988602 on test set
# Epoch -144 calculated
# Epoch 144 MSE 0.04019015339305493 on test set
# Epoch -145 calculated
# Epoch 145 MSE 0.040103348841907666 on test set
# Epoch -146 calculated
# Epoch 146 MSE 0.040173312376546096 on test set
# Epoch -147 calculated
# Epoch 147 MSE 0.04151204666044573 on test set
# Epoch -148 calculated
# Epoch 148 MSE 0.04332522890347855 on test set
# Epoch -149 calculated
# Epoch 149 MSE 0.03944489059125386 on test set
# Epoch -150 calculated
# Epoch 150 MSE 0.03934361066184678 on test set
# Epoch -151 calculated
# Epoch 151 MSE 0.040388731128029556 on test set
# Epoch -152 calculated
# Epoch 152 MSE 0.03923815727837705 on test set
# Epoch -153 calculated
# Epoch 153 MSE 0.03920353792742074 on test set
# Epoch -154 calculated
# Epoch 154 MSE 0.03958639802747877 on test set
# Epoch -155 calculated
# Epoch 155 MSE 0.039588800757938886 on test set
# Epoch -156 calculated
# Epoch 156 MSE 0.03835783095255567 on test set
# Epoch -157 calculated
# Epoch 157 MSE 0.038601887816434394 on test set
# Epoch -158 calculated
# Epoch 158 MSE 0.03978612859939347 on test set
# Epoch -159 calculated
# Epoch 159 MSE 0.03892888814687944 on test set
# Epoch -160 calculated
# Epoch 160 MSE 0.038702438832578276 on test set
# Epoch -161 calculated
# Epoch 161 MSE 0.0382502270388569 on test set
# Epoch -162 calculated
# Epoch 162 MSE 0.03984629844582839 on test set
# Epoch -163 calculated
# Epoch 163 MSE 0.03904350164181261 on test set
# Epoch -164 calculated
# Epoch 164 MSE 0.03817489866667565 on test set
# Epoch -165 calculated
# Epoch 165 MSE 0.0387319068556697 on test set
# Epoch -166 calculated
# Epoch 166 MSE 0.038554823356703655 on test set
# Epoch -167 calculated
# Epoch 167 MSE 0.03857222739259255 on test set
# Epoch -168 calculated
# Epoch 168 MSE 0.037976125684988565 on test set
# Epoch -169 calculated
# Epoch 169 MSE 0.03810867206853482 on test set
# Epoch -170 calculated
# Epoch 170 MSE 0.03827940108580626 on test set
# Epoch -171 calculated
# Epoch 171 MSE 0.03778436448573314 on test set
# Epoch -172 calculated
# Epoch 172 MSE 0.03914119270797134 on test set
# Epoch -173 calculated
# Epoch 173 MSE 0.037517237079157335 on test set
# Epoch -174 calculated
# Epoch 174 MSE 0.037213552735073395 on test set
# Epoch -175 calculated
# Epoch 175 MSE 0.03742055164977085 on test set
# Epoch -176 calculated
# Epoch 176 MSE 0.037600875844821864 on test set
# Epoch -177 calculated
# Epoch 177 MSE 0.03734441082700666 on test set
# Epoch -178 calculated
# Epoch 178 MSE 0.037855431405470076 on test set
# Epoch -179 calculated
# Epoch 179 MSE 0.03713171504717193 on test set
# Epoch -180 calculated
# Epoch 180 MSE 0.03693375766504114 on test set
# Epoch -181 calculated
# Epoch 181 MSE 0.03777672725141055 on test set
# Epoch -182 calculated
# Epoch 182 MSE 0.037638951630747486 on test set
# Epoch -183 calculated
# Epoch 183 MSE 0.03663955820467863 on test set
# Epoch -184 calculated
# Epoch 184 MSE 0.037292997573921044 on test set
# Epoch -185 calculated
# Epoch 185 MSE 0.037469723699837386 on test set
# Epoch -186 calculated
# Epoch 186 MSE 0.037000440167747325 on test set
# Epoch -187 calculated
# Epoch 187 MSE 0.03744921621633858 on test set
# Epoch -188 calculated
# Epoch 188 MSE 0.03718248144847044 on test set
# Epoch -189 calculated
# Epoch 189 MSE 0.03696178058962193 on test set
# Epoch -190 calculated
# Epoch 190 MSE 0.037001751194411694 on test set
# Epoch -191 calculated
# Epoch 191 MSE 0.03659729896923538 on test set
# Epoch -192 calculated
# Epoch 192 MSE 0.03735565260089768 on test set
# Epoch -193 calculated
# Epoch 193 MSE 0.03692745049979314 on test set
# Epoch -194 calculated
# Epoch 194 MSE 0.03649752966174362 on test set
# Epoch -195 calculated
# Epoch 195 MSE 0.03702319088492899 on test set
# Epoch -196 calculated
# Epoch 196 MSE 0.03661795399699461 on test set
# Epoch -197 calculated
# Epoch 197 MSE 0.03670345271852658 on test set
# Epoch -198 calculated
# Epoch 198 MSE 0.03623744087682554 on test set
# Epoch -199 calculated
# Epoch 199 MSE 0.03648175045544059 on test set
# Epoch -200 calculated
# Epoch 200 MSE 0.0385244965196502 on test set
# Epoch -201 calculated
# Epoch 201 MSE 0.03562059405769246 on test set
# Epoch -202 calculated
# Epoch 202 MSE 0.03664158958026232 on test set
# Epoch -203 calculated
# Epoch 203 MSE 0.036426147119296405 on test set
# Epoch -204 calculated
# Epoch 204 MSE 0.03596376264500864 on test set
# Epoch -205 calculated
# Epoch 205 MSE 0.03674808166654345 on test set
# Epoch -206 calculated
# Epoch 206 MSE 0.03544208640885287 on test set
# Epoch -207 calculated
# Epoch 207 MSE 0.03651755775758937 on test set
# Epoch -208 calculated
# Epoch 208 MSE 0.03539404138586409 on test set
# Epoch -209 calculated
# Epoch 209 MSE 0.03632917690289271 on test set
# Epoch -210 calculated
# Epoch 210 MSE 0.03633164488875912 on test set
# Epoch -211 calculated
# Epoch 211 MSE 0.03521836749455165 on test set
# Epoch -212 calculated
# Epoch 212 MSE 0.036169438546532116 on test set
# Epoch -213 calculated
# Epoch 213 MSE 0.036476194691625274 on test set
# Epoch -214 calculated
# Epoch 214 MSE 0.03593208223817363 on test set
# Epoch -215 calculated
# Epoch 215 MSE 0.0354791302411863 on test set
# Epoch -216 calculated
# Epoch 216 MSE 0.03746843114391918 on test set
# Epoch -217 calculated
# Epoch 217 MSE 0.03573062327072792 on test set
# Epoch -218 calculated
# Epoch 218 MSE 0.035188098246480184 on test set
# Epoch -219 calculated
# Epoch 219 MSE 0.0354806104420884 on test set
# Epoch -220 calculated
# Epoch 220 MSE 0.0358148917493015 on test set
# Epoch -221 calculated
# Epoch 221 MSE 0.035579248758348093 on test set
# Epoch -222 calculated
# Epoch 222 MSE 0.03580614636218364 on test set
# Epoch -223 calculated
# Epoch 223 MSE 0.035693302489766286 on test set
# Epoch -224 calculated
# Epoch 224 MSE 0.03535870303185796 on test set
# Epoch -225 calculated
# Epoch 225 MSE 0.03577180683413963 on test set
# Epoch -226 calculated
# Epoch 226 MSE 0.0351844453350771 on test set
# Epoch -227 calculated
# Epoch 227 MSE 0.03594971454172464 on test set
# Epoch -228 calculated
# Epoch 228 MSE 0.03741363325279626 on test set
# Epoch -229 calculated
# Epoch 229 MSE 0.03471658920017307 on test set
# Epoch -230 calculated
# Epoch 230 MSE 0.034434293482625604 on test set
# Epoch -231 calculated
# Epoch 231 MSE 0.0348712623894845 on test set
# Epoch -232 calculated
# Epoch 232 MSE 0.035661789006254586 on test set
# Epoch -233 calculated
# Epoch 233 MSE 0.035912862943877265 on test set
# Epoch -234 calculated
# Epoch 234 MSE 0.034920537385538714 on test set
# Epoch -235 calculated
# Epoch 235 MSE 0.035353430420463336 on test set
# Epoch -236 calculated
# Epoch 236 MSE 0.03479289253013215 on test set
# Epoch -237 calculated
# Epoch 237 MSE 0.03473775660743931 on test set
# Epoch -238 calculated
# Epoch 238 MSE 0.03538933200085968 on test set
# Epoch -239 calculated
# Epoch 239 MSE 0.03464617589187784 on test set
# Epoch -240 calculated
# Epoch 240 MSE 0.0345119544492585 on test set
# Epoch -241 calculated
# Epoch 241 MSE 0.035323192711234706 on test set
# Epoch -242 calculated
# Epoch 242 MSE 0.034983114660503696 on test set
# Epoch -243 calculated
# Epoch 243 MSE 0.03600534564574978 on test set
# Epoch -244 calculated
# Epoch 244 MSE 0.03425860878421807 on test set
# Epoch -245 calculated
# Epoch 245 MSE 0.034296499872484246 on test set
# Epoch -246 calculated
# Epoch 246 MSE 0.034078427931067364 on test set
# Epoch -247 calculated
# Epoch 247 MSE 0.03488645513754482 on test set
# Epoch -248 calculated
# Epoch 248 MSE 0.034655800803926703 on test set
# Epoch -249 calculated
# Epoch 249 MSE 0.03433455683061514 on test set
# Epoch -250 calculated
# Epoch 250 MSE 0.03458975723570419 on test set
# Epoch -251 calculated
# Epoch 251 MSE 0.03413798688398597 on test set
# Epoch -252 calculated
# Epoch 252 MSE 0.034600417218980405 on test set
# Epoch -253 calculated
# Epoch 253 MSE 0.03441412623048933 on test set
# Epoch -254 calculated
# Epoch 254 MSE 0.034459444100090865 on test set
# Epoch -255 calculated
# Epoch 255 MSE 0.036339099869983495 on test set
# Epoch -256 calculated
# Epoch 256 MSE 0.03445055366533883 on test set
# Epoch -257 calculated
# Epoch 257 MSE 0.03540420573081181 on test set
# Epoch -258 calculated
# Epoch 258 MSE 0.035679192161722925 on test set
# Epoch -259 calculated
# Epoch 259 MSE 0.03356998105593929 on test set
# Epoch -260 calculated
# Epoch 260 MSE 0.03473442368820388 on test set
# Epoch -261 calculated
# Epoch 261 MSE 0.0341578103028307 on test set
# Epoch -262 calculated
# Epoch 262 MSE 0.035037397995327124 on test set
# Epoch -263 calculated
# Epoch 263 MSE 0.03330261592953201 on test set
# Epoch -264 calculated
# Epoch 264 MSE 0.03464548163547062 on test set
# Epoch -265 calculated
# Epoch 265 MSE 0.03837406706446726 on test set
# Epoch -266 calculated
# Epoch 266 MSE 0.03381164910745476 on test set
# Epoch -267 calculated
# Epoch 267 MSE 0.033633108137972274 on test set
# Epoch -268 calculated
# Epoch 268 MSE 0.033877491900118246 on test set
# Epoch -269 calculated
# Epoch 269 MSE 0.03455153390925254 on test set
# Epoch -270 calculated
# Epoch 270 MSE 0.033584524407997064 on test set
# Epoch -271 calculated
# Epoch 271 MSE 0.03312454038519567 on test set
# Epoch -272 calculated
# Epoch 272 MSE 0.03434308805339953 on test set
# Epoch -273 calculated
# Epoch 273 MSE 0.03349531040235745 on test set
# Epoch -274 calculated
# Epoch 274 MSE 0.03347873477957812 on test set
# Epoch -275 calculated
# Epoch 275 MSE 0.03576897455206356 on test set
# Epoch -276 calculated
# Epoch 276 MSE 0.03427189299203017 on test set
# Epoch -277 calculated
# Epoch 277 MSE 0.03486150025368963 on test set
# Epoch -278 calculated
# Epoch 278 MSE 0.03377590445610553 on test set
# Epoch -279 calculated
# Epoch 279 MSE 0.03422468064956289 on test set
# Epoch -280 calculated
# Epoch 280 MSE 0.033116342792770495 on test set
# Epoch -281 calculated
# Epoch 281 MSE 0.03486769817023273 on test set
# Epoch -282 calculated
# Epoch 282 MSE 0.034073101300213925 on test set
# Epoch -283 calculated
# Epoch 283 MSE 0.03386482528618391 on test set
# Epoch -284 calculated
# Epoch 284 MSE 0.03311706359976659 on test set
# Epoch -285 calculated
# Epoch 285 MSE 0.03305659687197316 on test set
# Epoch -286 calculated
# Epoch 286 MSE 0.03499055311164751 on test set
# Epoch -287 calculated
# Epoch 287 MSE 0.033446204455735734 on test set
# Epoch -288 calculated
# Epoch 288 MSE 0.03217764796978009 on test set
# Epoch -289 calculated
# Epoch 289 MSE 0.03472779561236279 on test set
# Epoch -290 calculated
# Epoch 290 MSE 0.03317804600939058 on test set
# Epoch -291 calculated
# Epoch 291 MSE 0.03314646406969209 on test set
# Epoch -292 calculated
# Epoch 292 MSE 0.035236799914037054 on test set
# Epoch -293 calculated
# Epoch 293 MSE 0.03309683964153882 on test set
# Epoch -294 calculated
# Epoch 294 MSE 0.0335476292982372 on test set
# Epoch -295 calculated
# Epoch 295 MSE 0.03277841299595861 on test set
# Epoch -296 calculated
# Epoch 296 MSE 0.033126865710063444 on test set
# Epoch -297 calculated
# Epoch 297 MSE 0.03394213224705074 on test set
# Epoch -298 calculated
# Epoch 298 MSE 0.04744249942505413 on test set
# Epoch -299 calculated
# Epoch 299 MSE 0.03203028884885968 on test set
# Epoch -300 calculated
# Epoch 300 MSE 0.032245760912706214 on test set
# Epoch -301 calculated
# Epoch 301 MSE 0.03315980144875472 on test set
# Epoch -302 calculated
# Epoch 302 MSE 0.03433895143202009 on test set
# Epoch -303 calculated
# Epoch 303 MSE 0.033388463570747096 on test set
# Epoch -304 calculated
# Epoch 304 MSE 0.03193808332946496 on test set
# Epoch -305 calculated
# Epoch 305 MSE 0.03249192627403554 on test set
# Epoch -306 calculated
# Epoch 306 MSE 0.03341755620224 on test set
# Epoch -307 calculated
# Epoch 307 MSE 0.034799228318180477 on test set
# Epoch -308 calculated
# Epoch 308 MSE 0.03318432276443816 on test set
# Epoch -309 calculated
# Epoch 309 MSE 0.03420886119738627 on test set
# Epoch -310 calculated
# Epoch 310 MSE 0.03338824225952765 on test set
# Epoch -311 calculated
# Epoch 311 MSE 0.03285841621833479 on test set
# Epoch -312 calculated
# Epoch 312 MSE 0.03240662241008993 on test set
# Epoch -313 calculated
# Epoch 313 MSE 0.032820602455831495 on test set
# Epoch -314 calculated
# Epoch 314 MSE 0.03178097045490159 on test set
# Epoch -315 calculated
# Epoch 315 MSE 0.033736910762812926 on test set
# Epoch -316 calculated
# Epoch 316 MSE 0.03268878209866521 on test set
# Epoch -317 calculated
# Epoch 317 MSE 0.03148688826450957 on test set
# Epoch -318 calculated
# Epoch 318 MSE 0.03242428201079006 on test set
# Epoch -319 calculated
# Epoch 319 MSE 0.031010918735545265 on test set
# Epoch -320 calculated
# Epoch 320 MSE 0.032994459203291804 on test set
# Epoch -321 calculated
# Epoch 321 MSE 0.031454988163364714 on test set
# Epoch -322 calculated
# Epoch 322 MSE 0.033212696681798624 on test set
# Epoch -323 calculated
# Epoch 323 MSE 0.03291103615119313 on test set
# Epoch -324 calculated
# Epoch 324 MSE 0.031506882485807734 on test set
# Epoch -325 calculated
# Epoch 325 MSE 0.031941978357131355 on test set
# Epoch -326 calculated
# Epoch 326 MSE 0.03209845597873314 on test set
# Epoch -327 calculated
# Epoch 327 MSE 0.033305709126635406 on test set
# Epoch -328 calculated
# Epoch 328 MSE 0.032395344228031975 on test set
# Epoch -329 calculated
# Epoch 329 MSE 0.031718071603112206 on test set
# Epoch -330 calculated
# Epoch 330 MSE 0.032588809655695244 on test set
# Epoch -331 calculated
# Epoch 331 MSE 0.03102581026054305 on test set
# Epoch -332 calculated
# Epoch 332 MSE 0.03137436183473619 on test set
# Epoch -333 calculated
# Epoch 333 MSE 0.03234020396718706 on test set
# Epoch -334 calculated
# Epoch 334 MSE 0.031576577512993045 on test set
# Epoch -335 calculated
# Epoch 335 MSE 0.03199924090604627 on test set
# Epoch -336 calculated
# Epoch 336 MSE 0.031360185179062645 on test set
# Epoch -337 calculated
# Epoch 337 MSE 0.030497909987113866 on test set
# Epoch -338 calculated
# Epoch 338 MSE 0.031618658101870464 on test set
# Epoch -339 calculated
# Epoch 339 MSE 0.03195733548026404 on test set
# Epoch -340 calculated
# Epoch 340 MSE 0.030866695888643204 on test set
# Epoch -341 calculated
# Epoch 341 MSE 0.030860163120691883 on test set
# Epoch -342 calculated
# Epoch 342 MSE 0.030507642944171003 on test set
# Epoch -343 calculated
# Epoch 343 MSE 0.032507734284167936 on test set
# Epoch -344 calculated
# Epoch 344 MSE 0.031532245796413456 on test set
# Epoch -345 calculated
# Epoch 345 MSE 0.032520801405588065 on test set
# Epoch -346 calculated
# Epoch 346 MSE 0.031566580341689125 on test set
# Epoch -347 calculated
# Epoch 347 MSE 0.031532782002405634 on test set
# Epoch -348 calculated
# Epoch 348 MSE 0.03369477009661841 on test set
# Epoch -349 calculated
# Epoch 349 MSE 0.03052847181781358 on test set
# Epoch -350 calculated
# Epoch 350 MSE 0.03284792149205667 on test set
# Epoch -351 calculated
# Epoch 351 MSE 0.030628476777073428 on test set
# Epoch -352 calculated
# Epoch 352 MSE 0.03437929845429869 on test set
# Epoch -353 calculated
# Epoch 353 MSE 0.031106386597202447 on test set
# Epoch -354 calculated
# Epoch 354 MSE 0.034424296321062815 on test set
# Epoch -355 calculated
# Epoch 355 MSE 0.03350822019382114 on test set
# Epoch -356 calculated
# Epoch 356 MSE 0.03210502779202486 on test set
# Epoch -357 calculated
# Epoch 357 MSE 0.033478863973278754 on test set
# Epoch -358 calculated
# Epoch 358 MSE 0.03159515321793997 on test set
# Epoch -359 calculated
# Epoch 359 MSE 0.03295594731857755 on test set
# Epoch -360 calculated
# Epoch 360 MSE 0.03030438823726168 on test set
# Epoch -361 calculated
# Epoch 361 MSE 0.03163272482771907 on test set
# Epoch -362 calculated
# Epoch 362 MSE 0.032268278456553764 on test set
# Epoch -363 calculated
# Epoch 363 MSE 0.030213106977479875 on test set
# Epoch -364 calculated
# Epoch 364 MSE 0.030244297201076752 on test set
# Epoch -365 calculated
# Epoch 365 MSE 0.03185275514921712 on test set
# Epoch -366 calculated
# Epoch 366 MSE 0.03161932561961422 on test set
# Epoch -367 calculated
# Epoch 367 MSE 0.03016870080983631 on test set
# Epoch -368 calculated
# Epoch 368 MSE 0.03116467906721407 on test set
# Epoch -369 calculated
# Epoch 369 MSE 0.03047898165934533 on test set
# Epoch -370 calculated
# Epoch 370 MSE 0.030185562705841554 on test set
# Epoch -371 calculated
# Epoch 371 MSE 0.03131907653291307 on test set
# Epoch -372 calculated
# Epoch 372 MSE 0.031616375457758666 on test set
# Epoch -373 calculated
# Epoch 373 MSE 0.030338500345652015 on test set
# Epoch -374 calculated
# Epoch 374 MSE 0.0308824993340015 on test set
# Epoch -375 calculated
# Epoch 375 MSE 0.03322015959589963 on test set
# Epoch -376 calculated
# Epoch 376 MSE 0.029619476830935087 on test set
# Epoch -377 calculated
# Epoch 377 MSE 0.030186626066983753 on test set
# Epoch -378 calculated
# Epoch 378 MSE 0.033577445023263944 on test set
# Epoch -379 calculated
# Epoch 379 MSE 0.02973015689890028 on test set
# Epoch -380 calculated
# Epoch 380 MSE 0.0302670315815634 on test set
# Epoch -381 calculated
# Epoch 381 MSE 0.031447265006900704 on test set
# Epoch -382 calculated
# Epoch 382 MSE 0.03028457853020874 on test set
# Epoch -383 calculated
# Epoch 383 MSE 0.03052563942296444 on test set
# Epoch -384 calculated
# Epoch 384 MSE 0.03117681821304455 on test set
# Epoch -385 calculated
# Epoch 385 MSE 0.029671458828647263 on test set
# Epoch -386 calculated
# Epoch 386 MSE 0.02986218021861506 on test set
# Epoch -387 calculated
# Epoch 387 MSE 0.030365418423444753 on test set
# Epoch -388 calculated
# Epoch 388 MSE 0.030001218747296204 on test set
# Epoch -389 calculated
# Epoch 389 MSE 0.030812411385893072 on test set
# Epoch -390 calculated
# Epoch 390 MSE 0.031570702122453546 on test set
# Epoch -391 calculated
# Epoch 391 MSE 0.02979154037345428 on test set
# Epoch -392 calculated
# Epoch 392 MSE 0.030198425768498627 on test set
# Epoch -393 calculated
# Epoch 393 MSE 0.035167634808113794 on test set
# Epoch -394 calculated
# Epoch 394 MSE 0.029931457731116697 on test set
# Epoch -395 calculated
# Epoch 395 MSE 0.030370597300881236 on test set
# Epoch -396 calculated
# Epoch 396 MSE 0.03048743446008823 on test set
# Epoch -397 calculated
# Epoch 397 MSE 0.02936859240846757 on test set
# Epoch -398 calculated
# Epoch 398 MSE 0.029286544268139737 on test set
# Epoch -399 calculated
# Epoch 399 MSE 0.029550798413554475 on test set
# Epoch -400 calculated
# Epoch 400 MSE 0.029992261321407924 on test set
# Epoch -401 calculated
# Epoch 401 MSE 0.029923923512924354 on test set
# Epoch -402 calculated
# Epoch 402 MSE 0.029182781899603324 on test set
# Epoch -403 calculated
# Epoch 403 MSE 0.029221324292599212 on test set
# Epoch -404 calculated
# Epoch 404 MSE 0.03070879202122737 on test set
# Epoch -405 calculated
# Epoch 405 MSE 0.030543357393762 on test set
# Epoch -406 calculated
# Epoch 406 MSE 0.029162683193285247 on test set
# Epoch -407 calculated
# Epoch 407 MSE 0.02940766586677027 on test set
# Epoch -408 calculated
# Epoch 408 MSE 0.029603534998161346 on test set
# Epoch -409 calculated
# Epoch 409 MSE 0.030568712780819865 on test set
# Epoch -410 calculated
# Epoch 410 MSE 0.0295867187733849 on test set
# Epoch -411 calculated
# Epoch 411 MSE 0.029516394872467384 on test set
# Epoch -412 calculated
# Epoch 412 MSE 0.03073758059216219 on test set
# Epoch -413 calculated
# Epoch 413 MSE 0.030760098347815408 on test set
# Epoch -414 calculated
# Epoch 414 MSE 0.031034363146022457 on test set
# Epoch -415 calculated
# Epoch 415 MSE 0.02900558271087844 on test set
# Epoch -416 calculated
# Epoch 416 MSE 0.029377372499411584 on test set
# Epoch -417 calculated
# Epoch 417 MSE 0.029808382010410025 on test set
# Epoch -418 calculated
# Epoch 418 MSE 0.031001800734784594 on test set
# Epoch -419 calculated
# Epoch 419 MSE 0.02973300158916067 on test set
# Epoch -420 calculated
# Epoch 420 MSE 0.0291611161993384 on test set
# Epoch -421 calculated
# Epoch 421 MSE 0.028431430548641577 on test set
# Epoch -422 calculated
# Epoch 422 MSE 0.031217833393001052 on test set
# Epoch -423 calculated
# Epoch 423 MSE 0.028916560294667992 on test set
# Epoch -424 calculated
# Epoch 424 MSE 0.029829804701797538 on test set
# Epoch -425 calculated
# Epoch 425 MSE 0.028728528476957362 on test set
# Epoch -426 calculated
# Epoch 426 MSE 0.029716528597160022 on test set
# Epoch -427 calculated
# Epoch 427 MSE 0.031222718158338828 on test set
# Epoch -428 calculated
# Epoch 428 MSE 0.028387668531896774 on test set
# Epoch -429 calculated
# Epoch 429 MSE 0.029447333522450374 on test set
# Epoch -430 calculated
# Epoch 430 MSE 0.029722725963431947 on test set
# Epoch -431 calculated
# Epoch 431 MSE 0.02976922161912558 on test set
# Epoch -432 calculated
# Epoch 432 MSE 0.029946446947313674 on test set
# Epoch -433 calculated
# Epoch 433 MSE 0.03183957950467185 on test set
# Epoch -434 calculated
# Epoch 434 MSE 0.028321503143991972 on test set
# Epoch -435 calculated
# Epoch 435 MSE 0.03173746946744421 on test set
# Epoch -436 calculated
# Epoch 436 MSE 0.028582668869833225 on test set
# Epoch -437 calculated
# Epoch 437 MSE 0.03173353401199193 on test set
# Epoch -438 calculated
# Epoch 438 MSE 0.028584403653952352 on test set
# Epoch -439 calculated
# Epoch 439 MSE 0.028592359595283747 on test set
# Epoch -440 calculated
# Epoch 440 MSE 0.028493173853701023 on test set
# Epoch -441 calculated
# Epoch 441 MSE 0.03146280140269955 on test set
# Epoch -442 calculated
# Epoch 442 MSE 0.029537334020907892 on test set
# Epoch -443 calculated
# Epoch 443 MSE 0.028923684310819816 on test set
# Epoch -444 calculated
# Epoch 444 MSE 0.02832749255040421 on test set
# Epoch -445 calculated
# Epoch 445 MSE 0.029649037665457095 on test set
# Epoch -446 calculated
# Epoch 446 MSE 0.02938626034190169 on test set
# Epoch -447 calculated
# Epoch 447 MSE 0.028469767966103936 on test set
# Epoch -448 calculated
# Epoch 448 MSE 0.028118195414364604 on test set
# Epoch -449 calculated
# Epoch 449 MSE 0.02907260943405782 on test set
# Epoch -450 calculated
# Epoch 450 MSE 0.028301494085791745 on test set
# Epoch -451 calculated
# Epoch 451 MSE 0.028435069095144573 on test set
# Epoch -452 calculated
# Epoch 452 MSE 0.028894927539702665 on test set
# Epoch -453 calculated
# Epoch 453 MSE 0.0288404275838543 on test set
# Epoch -454 calculated
# Epoch 454 MSE 0.028749926837430082 on test set
# Epoch -455 calculated
# Epoch 455 MSE 0.029028576925104174 on test set
# Epoch -456 calculated
# Epoch 456 MSE 0.028640840043475314 on test set
# Epoch -457 calculated
# Epoch 457 MSE 0.02858350877743696 on test set
# Epoch -458 calculated
# Epoch 458 MSE 0.029589213988905995 on test set
# Epoch -459 calculated
# Epoch 459 MSE 0.028367950070936666 on test set
# Epoch -460 calculated
# Epoch 460 MSE 0.02795384060162918 on test set
# Epoch -461 calculated
# Epoch 461 MSE 0.028463174734302384 on test set
# Epoch -462 calculated
# Epoch 462 MSE 0.029471826245135717 on test set
# Epoch -463 calculated
# Epoch 463 MSE 0.027055802938883187 on test set
# Epoch -464 calculated
# Epoch 464 MSE 0.02729640910403902 on test set
# Epoch -465 calculated
# Epoch 465 MSE 0.027984028881532223 on test set
# Epoch -466 calculated
# Epoch 466 MSE 0.029583065152573976 on test set
# Epoch -467 calculated
# Epoch 467 MSE 0.027783269908575253 on test set
# Epoch -468 calculated
# Epoch 468 MSE 0.028246114706845217 on test set
# Epoch -469 calculated
# Epoch 469 MSE 0.02953409488301968 on test set
# Epoch -470 calculated
# Epoch 470 MSE 0.028086725926993534 on test set
# Epoch -471 calculated
# Epoch 471 MSE 0.028926465767994194 on test set
# Epoch -472 calculated
# Epoch 472 MSE 0.027665650428888827 on test set
# Epoch -473 calculated
# Epoch 473 MSE 0.028100218960711694 on test set
# Epoch -474 calculated
# Epoch 474 MSE 0.02811395483047434 on test set
# Epoch -475 calculated
# Epoch 475 MSE 0.028068945138473456 on test set
# Epoch -476 calculated
# Epoch 476 MSE 0.028084889310494025 on test set
# Epoch -477 calculated
# Epoch 477 MSE 0.027896247045922116 on test set
# Epoch -478 calculated
# Epoch 478 MSE 0.027640060355509224 on test set
# Epoch -479 calculated
# Epoch 479 MSE 0.02777285522294614 on test set
# Epoch -480 calculated
# Epoch 480 MSE 0.027668276373990927 on test set
# Epoch -481 calculated
# Epoch 481 MSE 0.028472592497438134 on test set
# Epoch -482 calculated
# Epoch 482 MSE 0.030509448554262558 on test set
# Epoch -483 calculated
# Epoch 483 MSE 0.027871840893359364 on test set
# Epoch -484 calculated
# Epoch 484 MSE 0.027099201177476818 on test set
# Epoch -485 calculated
# Epoch 485 MSE 0.027948970607776187 on test set
# Epoch -486 calculated
# Epoch 486 MSE 0.027309900732656867 on test set
# Epoch -487 calculated
# Epoch 487 MSE 0.027983006389547985 on test set
# Epoch -488 calculated
# Epoch 488 MSE 0.028837499064617956 on test set
# Epoch -489 calculated
# Epoch 489 MSE 0.029305539264691365 on test set
# Epoch -490 calculated
# Epoch 490 MSE 0.027696111900789015 on test set
# Epoch -491 calculated
# Epoch 491 MSE 0.028355162634555366 on test set
# Epoch -492 calculated
# Epoch 492 MSE 0.02773346285693197 on test set
# Epoch -493 calculated
# Epoch 493 MSE 0.028156852125128598 on test set
# Epoch -494 calculated
# Epoch 494 MSE 0.027487148687643834 on test set
# Epoch -495 calculated
# Epoch 495 MSE 0.027522470021320064 on test set
# Epoch -496 calculated
# Epoch 496 MSE 0.027613404790824563 on test set
# Epoch -497 calculated
# Epoch 497 MSE 0.027045999896647008 on test set
# Epoch -498 calculated
# Epoch 498 MSE 0.027772664197179744 on test set
# Epoch -499 calculated
# Epoch 499 MSE 0.027215753911241484 on test set
# Epoch -500 calculated
# Epoch 500 MSE 0.031501609497891984 on test set
# Epoch -501 calculated
# Epoch 501 MSE 0.028672352972356503 on test set
# Epoch -502 calculated
# Epoch 502 MSE 0.027246397170108558 on test set
# Epoch -503 calculated
# Epoch 503 MSE 0.027044631248763787 on test set
# Epoch -504 calculated
# Epoch 504 MSE 0.044340538996037224 on test set
# Epoch -505 calculated
# Epoch 505 MSE 0.027675578099499394 on test set
# Epoch -506 calculated
# Epoch 506 MSE 0.02682913769464535 on test set
# Epoch -507 calculated
# Epoch 507 MSE 0.026980006698266643 on test set
# Epoch -508 calculated
# Epoch 508 MSE 0.027080388953507634 on test set
# Epoch -509 calculated
# Epoch 509 MSE 0.02887088276434773 on test set
# Epoch -510 calculated
# Epoch 510 MSE 0.027098662257270808 on test set
# Epoch -511 calculated
# Epoch 511 MSE 0.027061946774805085 on test set
# Epoch -512 calculated
# Epoch 512 MSE 0.027445953517243094 on test set
# Epoch -513 calculated
# Epoch 513 MSE 0.027108674493223676 on test set
# Epoch -514 calculated
# Epoch 514 MSE 0.027086954863887933 on test set
# Epoch -515 calculated
# Epoch 515 MSE 0.026719171436497397 on test set
# Epoch -516 calculated
# Epoch 516 MSE 0.027453566770767546 on test set
# Epoch -517 calculated
# Epoch 517 MSE 0.027272751303567794 on test set
# Epoch -518 calculated
# Epoch 518 MSE 0.027017724444690562 on test set
# Epoch -519 calculated
# Epoch 519 MSE 0.027684571640672808 on test set
# Epoch -520 calculated
# Epoch 520 MSE 0.026977736901233364 on test set
# Epoch -521 calculated
# Epoch 521 MSE 0.027138719828104632 on test set
# Epoch -522 calculated
# Epoch 522 MSE 0.027094970348190986 on test set
# Epoch -523 calculated
# Epoch 523 MSE 0.027462757953551575 on test set
# Epoch -524 calculated
# Epoch 524 MSE 0.026839512488081693 on test set
# Epoch -525 calculated
# Epoch 525 MSE 0.026615979358025087 on test set
# Epoch -526 calculated
# Epoch 526 MSE 0.026742775010285373 on test set
# Epoch -527 calculated
# Epoch 527 MSE 0.02722642281085927 on test set
# Epoch -528 calculated
# Epoch 528 MSE 0.027872434547294416 on test set
# Epoch -529 calculated
# Epoch 529 MSE 0.027153128183873422 on test set
# Epoch -530 calculated
# Epoch 530 MSE 0.027366055160548856 on test set
# Epoch -531 calculated
# Epoch 531 MSE 0.027100390040329533 on test set
# Epoch -532 calculated
# Epoch 532 MSE 0.02718545024433951 on test set
# Epoch -533 calculated
# Epoch 533 MSE 0.02781599784542842 on test set
# Epoch -534 calculated
# Epoch 534 MSE 0.026815143384214493 on test set
# Epoch -535 calculated
# Epoch 535 MSE 0.026868194479788873 on test set
# Epoch -536 calculated
# Epoch 536 MSE 0.02751358186982768 on test set
# Epoch -537 calculated
# Epoch 537 MSE 0.02717387076313238 on test set
# Epoch -538 calculated
# Epoch 538 MSE 0.026759936558859842 on test set
# Epoch -539 calculated
# Epoch 539 MSE 0.026885987527994194 on test set
# Epoch -540 calculated
# Epoch 540 MSE 0.027230959723326877 on test set
# Epoch -541 calculated
# Epoch 541 MSE 0.02659623250340441 on test set
# Epoch -542 calculated
# Epoch 542 MSE 0.02721877945418162 on test set
# Epoch -543 calculated
# Epoch 543 MSE 0.026878256350605714 on test set
# Epoch -544 calculated
# Epoch 544 MSE 0.02699003355035066 on test set
# Epoch -545 calculated
# Epoch 545 MSE 0.02710407175414946 on test set
# Epoch -546 calculated
# Epoch 546 MSE 0.0268336658038845 on test set
# Epoch -547 calculated
# Epoch 547 MSE 0.026660934830649678 on test set
# Epoch -548 calculated
# Epoch 548 MSE 0.026820610679054196 on test set
# Epoch -549 calculated
# Epoch 549 MSE 0.027259559605985362 on test set
# Epoch -550 calculated
# Epoch 550 MSE 0.026913113098175623 on test set
# Epoch -551 calculated
# Epoch 551 MSE 0.027908450787768935 on test set
# Epoch -552 calculated
# Epoch 552 MSE 0.029500176951445405 on test set
# Epoch -553 calculated
# Epoch 553 MSE 0.026728615341043507 on test set
# Epoch -554 calculated
# Epoch 554 MSE 0.02625653707054909 on test set
# Epoch -555 calculated
# Epoch 555 MSE 0.026455897983557183 on test set
# Epoch -556 calculated
# Epoch 556 MSE 0.026597929644115732 on test set
# Epoch -557 calculated
# Epoch 557 MSE 0.026799595179127743 on test set
# Epoch -558 calculated
# Epoch 558 MSE 0.02634588669929436 on test set
# Epoch -559 calculated
# Epoch 559 MSE 0.027723451568078164 on test set
# Epoch -560 calculated
# Epoch 560 MSE 0.026224943831946696 on test set
# Epoch -561 calculated
# Epoch 561 MSE 0.026401100827604346 on test set
# Epoch -562 calculated
# Epoch 562 MSE 0.027827093239267683 on test set
# Epoch -563 calculated
# Epoch 563 MSE 0.027240319431772728 on test set
# Epoch -564 calculated
# Epoch 564 MSE 0.02861279362597885 on test set
# Epoch -565 calculated
# Epoch 565 MSE 0.026659842995881953 on test set
# Epoch -566 calculated
# Epoch 566 MSE 0.026532567555902754 on test set
# Epoch -567 calculated
# Epoch 567 MSE 0.027044075526550623 on test set
# Epoch -568 calculated
# Epoch 568 MSE 0.027200342864855984 on test set
# Epoch -569 calculated
# Epoch 569 MSE 0.02631049870335683 on test set
# Epoch -570 calculated
# Epoch 570 MSE 0.02678166503819094 on test set
# Epoch -571 calculated
# Epoch 571 MSE 0.02722745681878503 on test set
# Epoch -572 calculated
# Epoch 572 MSE 0.026779070758954627 on test set
# Epoch -573 calculated
# Epoch 573 MSE 0.026901638200530376 on test set
# Epoch -574 calculated
# Epoch 574 MSE 0.026526258954050162 on test set
# Epoch -575 calculated
# Epoch 575 MSE 0.026088215184985896 on test set
# Epoch -576 calculated
# Epoch 576 MSE 0.026230181227475717 on test set
# Epoch -577 calculated
# Epoch 577 MSE 0.02653469869976316 on test set
# Epoch -578 calculated
# Epoch 578 MSE 0.02640145167171756 on test set
# Epoch -579 calculated
# Epoch 579 MSE 0.026964139555946585 on test set
# Epoch -580 calculated
# Epoch 580 MSE 0.026418078947496707 on test set
# Epoch -581 calculated
# Epoch 581 MSE 0.026872437577602503 on test set
# Epoch -582 calculated
# Epoch 582 MSE 0.027059219381264245 on test set
# Epoch -583 calculated
# Epoch 583 MSE 0.026274250651650913 on test set
# Epoch -584 calculated
# Epoch 584 MSE 0.026779075747816638 on test set
# Epoch -585 calculated
# Epoch 585 MSE 0.026640527828688847 on test set
# Epoch -586 calculated
# Epoch 586 MSE 0.026747147772611394 on test set
# Epoch -587 calculated
# Epoch 587 MSE 0.026253943216461323 on test set
# Epoch -588 calculated
# Epoch 588 MSE 0.026400269679270148 on test set
# Epoch -589 calculated
# Epoch 589 MSE 0.026092228067632475 on test set
# Epoch -590 calculated
# Epoch 590 MSE 0.026321668628614098 on test set
# Epoch -591 calculated
# Epoch 591 MSE 0.030605592566571947 on test set
# Epoch -592 calculated
# Epoch 592 MSE 0.02596217665765573 on test set
# Epoch -593 calculated
# Epoch 593 MSE 0.02648350612580912 on test set
# Epoch -594 calculated
# Epoch 594 MSE 0.05195014676604881 on test set
# Epoch -595 calculated
# Epoch 595 MSE 0.02662926957766584 on test set
# Epoch -596 calculated
# Epoch 596 MSE 0.02608013207969772 on test set
# Epoch -597 calculated
# Epoch 597 MSE 0.025784767702749872 on test set
# Epoch -598 calculated
# Epoch 598 MSE 0.025809950299258144 on test set
# Epoch -599 calculated
# Epoch 599 MSE 0.026713586640729363 on test set
# Epoch -600 calculated
# Epoch 600 MSE 0.02555635853403902 on test set
# Epoch -601 calculated
# Epoch 601 MSE 0.025812792235679845 on test set
# Epoch -602 calculated
# Epoch 602 MSE 0.028088248032704786 on test set
# Epoch -603 calculated
# Epoch 603 MSE 0.025907420421531924 on test set
# Epoch -604 calculated
# Epoch 604 MSE 0.026153345551299827 on test set
# Epoch -605 calculated
# Epoch 605 MSE 0.02590457895809773 on test set
# Epoch -606 calculated
# Epoch 606 MSE 0.026262146359646375 on test set
# Epoch -607 calculated
# Epoch 607 MSE 0.02650165701853933 on test set
# Epoch -608 calculated
# Epoch 608 MSE 0.02620781505287536 on test set
# Epoch -609 calculated
# Epoch 609 MSE 0.026416614968834996 on test set
# Epoch -610 calculated
# Epoch 610 MSE 0.025875855678187416 on test set
# Epoch -611 calculated
# Epoch 611 MSE 0.025561302685431598 on test set
# Epoch -612 calculated
# Epoch 612 MSE 0.025668915455679765 on test set
# Epoch -613 calculated
# Epoch 613 MSE 0.026154467619972973 on test set
# Epoch -614 calculated
# Epoch 614 MSE 0.026211195711276343 on test set
# Epoch -615 calculated
# Epoch 615 MSE 0.025883771734797834 on test set
# Epoch -616 calculated
# Epoch 616 MSE 0.026160899373625004 on test set
# Epoch -617 calculated
# Epoch 617 MSE 0.02625629406703721 on test set
# Epoch -618 calculated
# Epoch 618 MSE 0.02603368156334596 on test set
# Epoch -619 calculated
# Epoch 619 MSE 0.025995874843020347 on test set
# Epoch -620 calculated
# Epoch 620 MSE 0.025628334082298827 on test set
# Epoch -621 calculated
# Epoch 621 MSE 0.026384103701923334 on test set
# Epoch -622 calculated
# Epoch 622 MSE 0.026150032438105437 on test set
# Epoch -623 calculated
# Epoch 623 MSE 0.025862713380798194 on test set
# Epoch -624 calculated
# Epoch 624 MSE 0.02564084794214038 on test set
# Epoch -625 calculated
# Epoch 625 MSE 0.025643105225502106 on test set
# Epoch -626 calculated
# Epoch 626 MSE 0.025901387218888402 on test set
# Epoch -627 calculated
# Epoch 627 MSE 0.0257860898508965 on test set
# Epoch -628 calculated
# Epoch 628 MSE 0.025779714654295686 on test set
# Epoch -629 calculated
# Epoch 629 MSE 0.027016560913331832 on test set
# Epoch -630 calculated
# Epoch 630 MSE 0.025669162612746398 on test set
# Epoch -631 calculated
# Epoch 631 MSE 0.026108371970139974 on test set
# Epoch -632 calculated
# Epoch 632 MSE 0.026038628081285497 on test set
# Epoch -633 calculated
# Epoch 633 MSE 0.025376728550455262 on test set
# Epoch -634 calculated
# Epoch 634 MSE 0.02559631055955713 on test set
# Epoch -635 calculated
# Epoch 635 MSE 0.02597617139631146 on test set
# Epoch -636 calculated
# Epoch 636 MSE 0.025537024727448863 on test set
# Epoch -637 calculated
# Epoch 637 MSE 0.025776756898583317 on test set
# Epoch -638 calculated
# Epoch 638 MSE 0.026383073575976964 on test set
# Epoch -639 calculated
# Epoch 639 MSE 0.025562308712328743 on test set
# Epoch -640 calculated
# Epoch 640 MSE 0.02561401381059015 on test set
# Epoch -641 calculated
# Epoch 641 MSE 0.025725810038813992 on test set
# Epoch -642 calculated
# Epoch 642 MSE 0.025669281607377036 on test set
# Epoch -643 calculated
# Epoch 643 MSE 0.026694760635783576 on test set
# Epoch -644 calculated
# Epoch 644 MSE 0.0257837160661245 on test set
# Epoch -645 calculated
# Epoch 645 MSE 0.025597823671865555 on test set
# Epoch -646 calculated
# Epoch 646 MSE 0.025654546557316908 on test set
# Epoch -647 calculated
# Epoch 647 MSE 0.025532002495768365 on test set
# Epoch -648 calculated
# Epoch 648 MSE 0.02570118218812336 on test set
# Epoch -649 calculated
# Epoch 649 MSE 0.025993552160210348 on test set
# Epoch -650 calculated
# Epoch 650 MSE 0.025710278071242633 on test set
# Epoch -651 calculated
# Epoch 651 MSE 0.025736951602101533 on test set
# Epoch -652 calculated
# Epoch 652 MSE 0.02554484531814467 on test set
# Epoch -653 calculated
# Epoch 653 MSE 0.0256457415958766 on test set
# Epoch -654 calculated
# Epoch 654 MSE 0.026669996974921777 on test set
# Epoch -655 calculated
# Epoch 655 MSE 0.02554793199699068 on test set
# Epoch -656 calculated
# Epoch 656 MSE 0.02578664027948015 on test set
# Epoch -657 calculated
# Epoch 657 MSE 0.026635263419796513 on test set
# Epoch -658 calculated
# Epoch 658 MSE 0.025993263988897404 on test set
# Epoch -659 calculated
# Epoch 659 MSE 0.025540201413451518 on test set
# Epoch -660 calculated
# Epoch 660 MSE 0.025356998584617034 on test set
# Epoch -661 calculated
# Epoch 661 MSE 0.026635971335644038 on test set
# Epoch -662 calculated
# Epoch 662 MSE 0.026078910864522575 on test set
# Epoch -663 calculated
# Epoch 663 MSE 0.025410912318109522 on test set
# Epoch -664 calculated
# Epoch 664 MSE 0.025839760074689824 on test set
# Epoch -665 calculated
# Epoch 665 MSE 0.025896584878549837 on test set
# Epoch -666 calculated
# Epoch 666 MSE 0.025366685446221556 on test set
# Epoch -667 calculated
# Epoch 667 MSE 0.025380354835192333 on test set
# Epoch -668 calculated
# Epoch 668 MSE 0.02587635298842111 on test set
# Epoch -669 calculated
# Epoch 669 MSE 0.025162750122594925 on test set
# Epoch -670 calculated
# Epoch 670 MSE 0.026056692748428912 on test set
# Epoch -671 calculated
# Epoch 671 MSE 0.025580317341703913 on test set
# Epoch -672 calculated
# Epoch 672 MSE 0.025906461553150784 on test set
# Epoch -673 calculated
# Epoch 673 MSE 0.02629347988286051 on test set
# Epoch -674 calculated
# Epoch 674 MSE 0.025483742094778623 on test set
# Epoch -675 calculated
# Epoch 675 MSE 0.026318810602421385 on test set
# Epoch -676 calculated
# Epoch 676 MSE 0.025505504838990473 on test set
# Epoch -677 calculated
# Epoch 677 MSE 0.025998720260728067 on test set
# Epoch -678 calculated
# Epoch 678 MSE 0.025444595053103907 on test set
# Epoch -679 calculated
# Epoch 679 MSE 0.025371188269256127 on test set
# Epoch -680 calculated
# Epoch 680 MSE 0.025713070080330573 on test set
# Epoch -681 calculated
# Epoch 681 MSE 0.026021022738257734 on test set
# Epoch -682 calculated
# Epoch 682 MSE 0.02568153235686044 on test set
# Epoch -683 calculated
# Epoch 683 MSE 0.025368358812811104 on test set
# Epoch -684 calculated
# Epoch 684 MSE 0.025671328854280234 on test set
# Epoch -685 calculated
# Epoch 685 MSE 0.02585901027032991 on test set
# Epoch -686 calculated
# Epoch 686 MSE 0.026028000189477027 on test set
# Epoch -687 calculated
# Epoch 687 MSE 0.025133912475030364 on test set
# Epoch -688 calculated
# ...
# Epoch -1336 calculated
# Epoch 1336 MSE 0.023105785665727102 on test set
# Epoch -1337 calculated
# Epoch 1337 MSE 0.023115759933312097 on test set
# Epoch -1338 calculated
# Epoch 1338 MSE 0.023164306315900756 on test set
# Epoch -1339 calculated
# Epoch 1339 MSE 0.024040715626178693 on test set
# Epoch -1340 calculated
# Epoch 1340 MSE 0.023308479418489066 on test set
# Epoch -1341 calculated
# Epoch 1341 MSE 0.023245574500025453 on test set
# Epoch -1342 calculated
# Epoch 1342 MSE 0.023127045066761238 on test set
# Epoch -1343 calculated
# Epoch 1343 MSE 0.02304346811026162 on test set
# Epoch -1344 calculated
# Epoch 1344 MSE 0.02329976086476163 on test set
# Epoch -1345 calculated
# Epoch 1345 MSE 0.023657745719507045 on test set
# Epoch -1346 calculated
# Epoch 1346 MSE 0.023614504183127494 on test set
# Epoch -1347 calculated
# Epoch 1347 MSE 0.02322593140736057 on test set
# Epoch -1348 calculated
# Epoch 1348 MSE 0.023039705106778736 on test set
# Epoch -1349 calculated
# Epoch 1349 MSE 0.023345473645383086 on test set
# Epoch -1350 calculated
# Epoch 1350 MSE 0.0244443938051677 on test set
# Epoch -1351 calculated
# Epoch 1351 MSE 0.024359673978952077 on test set
# Epoch -1352 calculated
# Epoch 1352 MSE 0.023245818498555587 on test set
# Epoch -1353 calculated
# Epoch 1353 MSE 0.02309405673498611 on test set
# Epoch -1354 calculated
# Epoch 1354 MSE 0.02291902475760652 on test set
# Epoch -1355 calculated
# Epoch 1355 MSE 0.022833361083480035 on test set
# Epoch -1356 calculated
# Epoch 1356 MSE 0.0230259266532662 on test set
# Epoch -1357 calculated
# Epoch 1357 MSE 0.023166383398987987 on test set
# Epoch -1358 calculated
# Epoch 1358 MSE 0.023097608656333826 on test set
# Epoch -1359 calculated
# Epoch 1359 MSE 0.02297052435814888 on test set
# Epoch -1360 calculated
# Epoch 1360 MSE 0.023296665228275972 on test set
# Epoch -1361 calculated
# Epoch 1361 MSE 0.023717217330749076 on test set
# Epoch -1362 calculated
# Epoch 1362 MSE 0.02390030052362729 on test set
# Epoch -1363 calculated
# Epoch 1363 MSE 0.02314687337829147 on test set
# Epoch -1364 calculated
# Epoch 1364 MSE 0.023446999525011954 on test set
# Epoch -1365 calculated
# Epoch 1365 MSE 0.02381737734056009 on test set
# Epoch -1366 calculated
# Epoch 1366 MSE 0.023493557108589885 on test set
# Epoch -1367 calculated
# Epoch 1367 MSE 0.02348988939817153 on test set
# Epoch -1368 calculated
# Epoch 1368 MSE 0.02310933610297253 on test set
# Epoch -1369 calculated
# Epoch 1369 MSE 0.02285420972615466 on test set
# Epoch -1370 calculated
# Epoch 1370 MSE 0.024162457222654664 on test set
# Epoch -1371 calculated
# Epoch 1371 MSE 0.02396081694918339 on test set
# Epoch -1372 calculated
# Epoch 1372 MSE 0.022933345399283052 on test set
# Epoch -1373 calculated
# Epoch 1373 MSE 0.02321078079930444 on test set
# Epoch -1374 calculated
# Epoch 1374 MSE 0.023361231211208457 on test set
# Epoch -1375 calculated
# Epoch 1375 MSE 0.023445133238258063 on test set
# Epoch -1376 calculated
# Epoch 1376 MSE 0.02338898210914413 on test set
# Epoch -1377 calculated
# Epoch 1377 MSE 0.02336584589382637 on test set
# Epoch -1378 calculated
# Epoch 1378 MSE 0.023785025684605752 on test set
# Epoch -1379 calculated
# Epoch 1379 MSE 0.023348115593077735 on test set
# Epoch -1380 calculated
# Epoch 1380 MSE 0.023170413010885484 on test set
# Epoch -1381 calculated
# Epoch 1381 MSE 0.023202237800156258 on test set
# Epoch -1382 calculated
# Epoch 1382 MSE 0.023014672824146633 on test set
# Epoch -1383 calculated
# Epoch 1383 MSE 0.02365014672812432 on test set
# Epoch -1384 calculated
# Epoch 1384 MSE 0.023627047763057397 on test set
# Epoch -1385 calculated
# Epoch 1385 MSE 0.023367002610889274 on test set
# Epoch -1386 calculated
# Epoch 1386 MSE 0.023649561608458793 on test set
# Epoch -1387 calculated
# Epoch 1387 MSE 0.023353904723048047 on test set
# Epoch -1388 calculated
# Epoch 1388 MSE 0.023473224339904144 on test set
# Epoch -1389 calculated
# Epoch 1389 MSE 0.02331726640674666 on test set
# Epoch -1390 calculated
# Epoch 1390 MSE 0.023352761846977817 on test set
# Epoch -1391 calculated
# Epoch 1391 MSE 0.0236879512578989 on test set
# Epoch -1392 calculated
# Epoch 1392 MSE 0.023509353489585223 on test set
# Epoch -1393 calculated
# Epoch 1393 MSE 0.023185078981808563 on test set
# Epoch -1394 calculated
# Epoch 1394 MSE 0.023356808680853505 on test set
# Epoch -1395 calculated
# Epoch 1395 MSE 0.023936136997640158 on test set
# Epoch -1396 calculated
# Epoch 1396 MSE 0.023119489764211583 on test set
# Epoch -1397 calculated
# Epoch 1397 MSE 0.023406277907797136 on test set
# Epoch -1398 calculated
# Epoch 1398 MSE 0.023138806178313792 on test set
# Epoch -1399 calculated
# Epoch 1399 MSE 0.023799603906027568 on test set
# Epoch -1400 calculated
# Epoch 1400 MSE 0.02318945452251709 on test set
# Epoch -1401 calculated
# Epoch 1401 MSE 0.02382677201208474 on test set
# Epoch -1402 calculated
# Epoch 1402 MSE 0.02328121929332183 on test set
# Epoch -1403 calculated
# Epoch 1403 MSE 0.023105175742661858 on test set
# Epoch -1404 calculated
# Epoch 1404 MSE 0.022974339039645172 on test set
# Epoch -1405 calculated
# Epoch 1405 MSE 0.023870147202848604 on test set
# Epoch -1406 calculated
# Epoch 1406 MSE 0.02382070720784676 on test set
# Epoch -1407 calculated
# Epoch 1407 MSE 0.02347675222466643 on test set
# Epoch -1408 calculated
# Epoch 1408 MSE 0.023689396946335744 on test set
# Epoch -1409 calculated
# Epoch 1409 MSE 0.02331854035141598 on test set
# Epoch -1410 calculated
# Epoch 1410 MSE 0.023141749166364273 on test set
# Epoch -1411 calculated
# Epoch 1411 MSE 0.02352803133450867 on test set
# Epoch -1412 calculated
# Epoch 1412 MSE 0.02313454474662358 on test set
# Epoch -1413 calculated
# Epoch 1413 MSE 0.023736964974272412 on test set
# Epoch -1414 calculated
# Epoch 1414 MSE 0.02329422942284108 on test set
# Epoch -1415 calculated
# Epoch 1415 MSE 0.0234442364288634 on test set
# Epoch -1416 calculated
# Epoch 1416 MSE 0.02369897029262015 on test set
# Epoch -1417 calculated
# Epoch 1417 MSE 0.023448567446100924 on test set
# Epoch -1418 calculated
# Epoch 1418 MSE 0.023215697162342137 on test set
# Epoch -1419 calculated
# Epoch 1419 MSE 0.023277024162758737 on test set
# Epoch -1420 calculated
# Epoch 1420 MSE 0.023463875407422084 on test set
# Epoch -1421 calculated
# Epoch 1421 MSE 0.023434656922388837 on test set
# Epoch -1422 calculated
# Epoch 1422 MSE 0.02318435635869547 on test set
# Epoch -1423 calculated
# Epoch 1423 MSE 0.022875198702491138 on test set
# Epoch -1424 calculated
# Epoch 1424 MSE 0.022981874942333516 on test set
# Epoch -1425 calculated
# Epoch 1425 MSE 0.023209508712881206 on test set
# Epoch -1426 calculated
# Epoch 1426 MSE 0.023885266695533446 on test set
# Epoch -1427 calculated
# Epoch 1427 MSE 0.023331264437429573 on test set
# Epoch -1428 calculated
# Epoch 1428 MSE 0.02375028309626855 on test set
# Epoch -1429 calculated
# Epoch 1429 MSE 0.023173915068155103 on test set
# Epoch -1430 calculated
# Epoch 1430 MSE 0.022922479886453268 on test set
# Epoch -1431 calculated
# Epoch 1431 MSE 0.024045078895395578 on test set
# Epoch -1432 calculated
# Epoch 1432 MSE 0.023265620007719933 on test set
# Epoch -1433 calculated
# Epoch 1433 MSE 0.023626612547290142 on test set
# Epoch -1434 calculated
# Epoch 1434 MSE 0.0235427546183171 on test set
# Epoch -1435 calculated
# Epoch 1435 MSE 0.023630865571446343 on test set
# Epoch -1436 calculated
# Epoch 1436 MSE 0.02344459950009853 on test set
# Epoch -1437 calculated
# Epoch 1437 MSE 0.023184896586990435 on test set
# Epoch -1438 calculated
# Epoch 1438 MSE 0.0238612515323517 on test set
# Epoch -1439 calculated
# Epoch 1439 MSE 0.023645495394943705 on test set
# Epoch -1440 calculated
# Epoch 1440 MSE 0.023220665805138548 on test set
# Epoch -1441 calculated
# Epoch 1441 MSE 0.02363090556139364 on test set
# Epoch -1442 calculated
# Epoch 1442 MSE 0.02342979077734527 on test set
# Epoch -1443 calculated
# Epoch 1443 MSE 0.023588824337534745 on test set
# Epoch -1444 calculated
# Epoch 1444 MSE 0.02349816470360778 on test set
# Epoch -1445 calculated
# Epoch 1445 MSE 0.02342408040038161 on test set
# Epoch -1446 calculated
# Epoch 1446 MSE 0.02363504498584489 on test set
# Epoch -1447 calculated
# Epoch 1447 MSE 0.02331659828974678 on test set
# Epoch -1448 calculated
# Epoch 1448 MSE 0.024794833996322155 on test set
# Epoch -1449 calculated
# Epoch 1449 MSE 0.0231309462506534 on test set
# Epoch -1450 calculated
# Epoch 1450 MSE 0.0231578445611868 on test set
# Epoch -1451 calculated
# Epoch 1451 MSE 0.023997145054915188 on test set
# Epoch -1452 calculated
# Epoch 1452 MSE 0.023212372335016353 on test set
# Epoch -1453 calculated
# Epoch 1453 MSE 0.02498095819900632 on test set
# Epoch -1454 calculated
# Epoch 1454 MSE 0.0235183150959046 on test set
# Epoch -1455 calculated
# Epoch 1455 MSE 0.02311388757101679 on test set
# Epoch -1456 calculated
# Epoch 1456 MSE 0.02423903566565333 on test set
# Epoch -1457 calculated
# Epoch 1457 MSE 0.02316338174733378 on test set
# Epoch -1458 calculated
# Epoch 1458 MSE 0.023196051247261505 on test set
# Epoch -1459 calculated
# Epoch 1459 MSE 0.023225874482968978 on test set
# Epoch -1460 calculated
# Epoch 1460 MSE 0.02476068027532455 on test set
# Epoch -1461 calculated
# Epoch 1461 MSE 0.023536202104276253 on test set
# Epoch -1462 calculated
# Epoch 1462 MSE 0.026286910252748433 on test set
# Epoch -1463 calculated
# Epoch 1463 MSE 0.022879420828279567 on test set
# Epoch -1464 calculated
# Epoch 1464 MSE 0.022670651434942034 on test set
# Epoch -1465 calculated
# Epoch 1465 MSE 0.02288097484849301 on test set
# Epoch -1466 calculated
# Epoch 1466 MSE 0.022786049672803562 on test set
# Epoch -1467 calculated
# Epoch 1467 MSE 0.023231731302540942 on test set
# Epoch -1468 calculated
# Epoch 1468 MSE 0.02687961381087788 on test set
# Epoch -1469 calculated
# Epoch 1469 MSE 0.02270252677313051 on test set
# Epoch -1470 calculated
# Epoch 1470 MSE 0.022768303932933536 on test set
# Epoch -1471 calculated
# Epoch 1471 MSE 0.023315672112801576 on test set
# Epoch -1472 calculated
# Epoch 1472 MSE 0.15437173649022604 on test set
# Epoch -1473 calculated
# Epoch 1473 MSE 0.16149465024538998 on test set
# Epoch -1474 calculated
# Epoch 1474 MSE 0.165534795372461 on test set
# Epoch -1475 calculated
# Epoch 1475 MSE 0.1551885654735802 on test set
# Epoch -1476 calculated
# Epoch 1476 MSE 0.15452724604479187 on test set
# Epoch -1477 calculated
# Epoch 1477 MSE 0.15372183288343455 on test set
# Epoch -1478 calculated
# Epoch 1478 MSE 0.15671789836213396 on test set
# Epoch -1479 calculated
# Epoch 1479 MSE 0.15484793277566053 on test set
# Epoch -1480 calculated
# Epoch 1480 MSE 0.14940302713664985 on test set
# Epoch -1481 calculated
# Epoch 1481 MSE 0.1474760657743778 on test set
# Epoch -1482 calculated
# Epoch 1482 MSE 0.14774231441818866 on test set
# Epoch -1483 calculated
# Epoch 1483 MSE 0.14947699453028426 on test set
# Epoch -1484 calculated
# Epoch 1484 MSE 0.14701596560898278 on test set
# Epoch -1485 calculated
# Epoch 1485 MSE 0.14628781025999005 on test set
# Epoch -1486 calculated
# Epoch 1486 MSE 0.1443633368356331 on test set
# Epoch -1487 calculated
# Epoch 1487 MSE 0.14304214324189193 on test set
# Epoch -1488 calculated
# Epoch 1488 MSE 0.14603574964124302 on test set
# Epoch -1489 calculated
# Epoch 1489 MSE 0.14230209316845024 on test set
# Epoch -1490 calculated
# Epoch 1490 MSE 0.13538782917713615 on test set
# Epoch -1491 calculated
# Epoch 1491 MSE 0.13096768081337828 on test set
# Epoch -1492 calculated
# Epoch 1492 MSE 0.12443537495010974 on test set
# Epoch -1493 calculated
# Epoch 1493 MSE 0.12455938604193309 on test set
# Epoch -1494 calculated
# Epoch 1494 MSE 0.15693162033438796 on test set
# Epoch -1495 calculated
# Epoch 1495 MSE 0.1602546035104909 on test set
# Epoch -1496 calculated
# Epoch 1496 MSE 0.1644205253128276 on test set
# Epoch -1497 calculated
# Epoch 1497 MSE 0.16701715539787648 on test set
# Epoch -1498 calculated
# Epoch 1498 MSE 0.19787255443959126 on test set
# Epoch -1499 calculated
# Epoch 1499 MSE 0.1881892431788778 on test set
# Epoch -1500 calculated
# Epoch 1500 MSE 0.1784433516050258 on test set
# Epoch -1501 calculated
# Epoch 1501 MSE 0.1741071432859154 on test set
# Epoch -1502 calculated
# Epoch 1502 MSE 0.16897078342749278 on test set
# Epoch -1503 calculated
# Epoch 1503 MSE 0.16614907096942225 on test set
# Epoch -1504 calculated
# Epoch 1504 MSE 0.18086261118017807 on test set
# Epoch -1505 calculated
# Epoch 1505 MSE 0.15703946156826368 on test set
# Epoch -1506 calculated
# Epoch 1506 MSE 0.15310653595309875 on test set
# Epoch -1507 calculated
# Epoch 1507 MSE 0.15119600709380052 on test set
# Epoch -1508 calculated
# Epoch 1508 MSE 0.1480291557064367 on test set
# Epoch -1509 calculated
# Epoch 1509 MSE 0.1459864844454559 on test set
# Epoch -1510 calculated
# Epoch 1510 MSE 0.14284124443719592 on test set
# Epoch -1511 calculated
# Epoch 1511 MSE 0.1390800025920261 on test set
# Epoch -1512 calculated
# Epoch 1512 MSE 0.13504125790915794 on test set
# Epoch -1513 calculated
# Epoch 1513 MSE 0.13108653209970902 on test set
# Epoch -1514 calculated
# Epoch 1514 MSE 0.12734535631852426 on test set
# Epoch -1515 calculated
# Epoch 1515 MSE 0.12169715939085782 on test set
# Epoch -1516 calculated
# Epoch 1516 MSE 0.11603171293238056 on test set
# Epoch -1517 calculated
# Epoch 1517 MSE 0.11098228429510142 on test set
# Epoch -1518 calculated
# Epoch 1518 MSE 0.1059252097763235 on test set
# Epoch -1519 calculated
# Epoch 1519 MSE 0.10230814554911623 on test set
# Epoch -1520 calculated
# Epoch 1520 MSE 0.09934870770857945 on test set
# Epoch -1521 calculated
# Epoch 1521 MSE 0.09682049127580797 on test set
# Epoch -1522 calculated
# Epoch 1522 MSE 0.0946981943185153 on test set
# Epoch -1523 calculated
# Epoch 1523 MSE 0.09269073987739547 on test set
# Epoch -1524 calculated
# Epoch 1524 MSE 0.09076766758379452 on test set
# Epoch -1525 calculated
# Epoch 1525 MSE 0.08905304111997625 on test set
# Epoch -1526 calculated
# Epoch 1526 MSE 0.08762026662021169 on test set
# Epoch -1527 calculated
# Epoch 1527 MSE 0.08624964203308765 on test set
# Epoch -1528 calculated
# Epoch 1528 MSE 0.08476457724904049 on test set
# Epoch -1529 calculated
# Epoch 1529 MSE 0.08334485782910199 on test set
# Epoch -1530 calculated
# Epoch 1530 MSE 0.08196799157836929 on test set
# Epoch -1531 calculated
# Epoch 1531 MSE 0.08092678266499297 on test set
# Epoch -1532 calculated
# Epoch 1532 MSE 0.07984415432069615 on test set
# Epoch -1533 calculated
# Epoch 1533 MSE 0.07857539088027667 on test set
# Epoch -1534 calculated
# Epoch 1534 MSE 0.07748051644548952 on test set
# Epoch -1535 calculated
# Epoch 1535 MSE 0.07639170038496197 on test set
# Epoch -1536 calculated
# Epoch 1536 MSE 0.07544875224298783 on test set
# Epoch -1537 calculated
# Epoch 1537 MSE 0.07437828493157511 on test set
# Epoch -1538 calculated
# Epoch 1538 MSE 0.07337425859978992 on test set
# Epoch -1539 calculated
# Epoch 1539 MSE 0.0723572602339675 on test set
# Epoch -1540 calculated
# Epoch 1540 MSE 0.07130217616514353 on test set
# Epoch -1541 calculated
# Epoch 1541 MSE 0.07053869939091281 on test set
# Epoch -1542 calculated
# Epoch 1542 MSE 0.06909396062497596 on test set
# Epoch -1543 calculated
# Epoch 1543 MSE 0.06794085929819095 on test set
# Epoch -1544 calculated
# Epoch 1544 MSE 0.06693828621753671 on test set
# Epoch -1545 calculated
# Epoch 1545 MSE 0.06588593810783883 on test set
# Epoch -1546 calculated
# Epoch 1546 MSE 0.06531596824618636 on test set
# Epoch -1547 calculated
# Epoch 1547 MSE 0.06428637020689075 on test set
# Epoch -1548 calculated
# Epoch 1548 MSE 0.06469777376513458 on test set
# Epoch -1549 calculated
# Epoch 1549 MSE 0.0631051001457792 on test set
# Epoch -1550 calculated
# Epoch 1550 MSE 0.062452270725754204 on test set
# Epoch -1551 calculated
# Epoch 1551 MSE 0.07187303614062848 on test set
# Epoch -1552 calculated
# Epoch 1552 MSE 0.06456467349903584 on test set
# Epoch -1553 calculated
# Epoch 1553 MSE 0.06245772796386512 on test set
# Epoch -1554 calculated
# Epoch 1554 MSE 0.06140012816819822 on test set
# Epoch -1555 calculated
# Epoch 1555 MSE 0.06071170765941258 on test set
# Training duration 02:00:00:54
# Number of training variable 40901
# INFO:tensorflow:Restoring parameters from experiments/2017-10-28-17-17/temp/myFinalModel.ckpt
# INFO:tensorflow:Froze 4 variables.
# Converted 4 variables to const ops.
# 138 ops in the final graph.
# done, good job kids

# %%
from show import *
# %matplotlib notebook
showPickle(nameFigEstimation)
# Out:
# <img src="data:image/png;base64,..." width="640">
